# %%
import pandas as pd
from sklearn.metrics import roc_auc_score,roc_curve,scorer
import dill

import warnings
warnings.simplefilter("ignore")
# Out:
# /home/irina/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X_test = pd.read_csv("data/X_test.csv")
y_test = pd.read_csv("data/y_test.csv")

# %%
with open('models/CatBoost_model.dill', 'rb') as in_strm:
    model = dill.load(in_strm)

# %%
pred = model.predict_proba(X_test)

# %%
roc_auc_score(y_score=pred[:, 1][:], y_true=y_test)
# Out:
# 0.7173382058790987

# %%
0.7173382058790987

# %%
X_test['pred'] = pred[:, 1][:]
X_test.sort_values(by='pred', ascending=True)
# Out:
#       gender      relevent_experience enrolled_university education_level  \
# 4196    Male  Has relevent experience       no_enrollment        Graduate
# 2237    Male  Has relevent experience       no_enrollment        Graduate
# 1871    Male  Has relevent experience       no_enrollment        Graduate
# 7013    Male  Has relevent experience       no_enrollment        Graduate
# 7427    Male  Has relevent experience       no_enrollment        Graduate
# ...      ...                      ...                 ...             ...
# 6780  Female   No relevent experience    Full time course        Graduate
# 7564  Female   No relevent experience    Full time course        Graduate
# 5284  Female   No relevent experience    Full time course        Graduate
# 5885  Female   No relevent experience    Full time course        Graduate
# 4450  Female   No relevent experience    Full time course        Graduate
#
#      major_discipline experience company_size    company_type last_new_job  \
# 4196            Other        >15     100-1000         Pvt Ltd          1-4
# 2237            Other        >15     100-1000         Pvt Ltd          1-4
# 1871             Arts        >15     100-1000  Funded Startup          1-4
# 7013             Arts        >15     100-1000  Funded Startup          1-4
# 7427            Other        >15         <100  Funded Startup          1-4
# ...               ...        ...          ...             ...          ...
# 6780             STEM         <2         <100           Other          1-4
# 7564             STEM         <2         <100           Other          1-4
# 5284             STEM         <2         <100           Other          1-4
# 5885             STEM         <2         <100           Other          1-4
# 4450             STEM         <2         <100           Other          1-4
#
#           pred
# 4196  0.070300
# 2237  0.070300
# 1871  0.070315
# 7013  0.070315
# 7427  0.070346
# ...        ...
# 6780  0.681395
# 7564  0.681395
# 5284  0.681395
# 5885  0.681395
# 4450  0.681395
#
# [7664 rows x 10 columns]
